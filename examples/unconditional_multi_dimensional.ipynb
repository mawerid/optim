# %%
import numpy as np
import matplotlib.pyplot as plt
from optim.UnconditionalMultiDim import (
    gauss_seidel,
    hooke_jeeves,
    rosenbrock,  # need fix
    powell,
    simplex,  # to do
    nelder_mead,  # to do
    gradient_descent,
    steepest_gradient_descent,
    conjugate_descent,
    newton,  # to do
    random_search_with_return,  # to do
    best_sample,  # to do
    complex,  # to do
    iterative_random_search,  # to do
    random_search_radius,  # to do
)

# %% [markdown]
# ## Himmelblau Function
#
# The Himmelblau function is a multi-modal function used to test optimization algorithms. It is defined as:
#
# $\ f(x, y) = (x^2 + y - 11)^2 + (x + y^2 - 7)^2 $
#
# ### Extremum Points
#
# The function has one local maximum and four local minima:
#
# - **Local Maximum:**
#   - $\ f(-0.270845, -0.923039) = 181.617 $
#
# - **Local Minima:**
#   - $\ f(3.0, 2.0) = 0.0 $
#   - $\ f(-2.805118, 3.131312) = 0.0 $
#   - $\ f(-3.779310, -3.283186) = 0.0 $
#   - $\ f(3.584428, -1.848126) = 0.0 $

# %%
func = lambda point: (point[0] ** 2 + point[1] - 11) ** 2 + (point[0] + point[1] ** 2 - 7) ** 2

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = func(np.array([x, y]))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

plt.show()

# %%
gauss_seidel.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [12.49511649  1.58022944], current point: [4. 0.], F(current point): 34.0
# Starting dimension 0 optimization
# Round: 0,	x: 3.506664954809325,	F'(x): 73.99999999968543,	F''(x): 149.9994795040038
# Round: 1,	x: 3.4005485028507447,	F'(x): 11.201687148698623,	F''(x): 105.56032492559096
# Round: 2,	x: 3.3957010413573863,	F'(x): 0.4690634726856046,	F''(x): 96.7647650895742
# Round: 3,	x: 3.3956910959765048,	F'(x): 0.00095843040170962,	F''(x): 96.36940134782888
# Starting dimension 1 optimization
# Round: 0,	x: -0.08548101410245958,	F'(x): 1.0614360385297061,	F''(x): -12.417213923754387
# Round: 1,	x: -0.25745634355493774,	F'(x): 2.1203754910992245,	F''(x): -12.32953295016159
# Round: 2,	x: -0.6179908334143343,	F'(x): 4.190071410281604,	F''(x): -11.621832385344531
# Round: 3,	x: -1.6124808267707953,	F'(x): 7.791099707965542,	F''(x): -7.834266568806924
# Round: 4,	x: -1.8421236159461418,	F'(x): 4.31358081165456,	F''(x): 18.783872235417217
# ...

# %%
hooke_jeeves.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [13.5819228   2.01908859], current point: [4. 0.], F(current point): 34.0
# Trial vector: [10. 10.]
# F(x): 34.0, F(x + h): 34274.0, F(x - h): 794.0
# Trial vector: [ 0. 10.]
# F(x): 34.0, F(x + h): 9634.0, F(x - h): 9434.0
# Trial vector: [0. 0.]
# Iteration: 0, previous point: [4. 0.], current point: [4. 0.], F(current point): 34.0
# Hello there
# Iteration: 1, previous point: [13.5819228   2.01908859], current point: [4. 0.], F(current point): 34.0
# Trial vector: [5. 5.]
# F(x): 34.0, F(x + h): 4904.0, F(x - h): 164.0
# Trial vector: [0. 5.]
# F(x): 34.0, F(x + h): 584.0, F(x - h): 484.0
# Trial vector: [0. 0.]
# Iteration: 1, previous point: [4. 0.], current point: [4. 0.], F(current point): 34.0
# Hello there
# Iteration: 2, previous point: [13.5819228   2.01908859], current point: [4. 0.], F(current point): 34.0
# Trial vector: [2.5 2.5]
# F(x): 34.0, F(x + h): 976.8125, F(x - h): 106.8125
# Trial vector: [0.  2.5]
# ...

# %%
rosenbrock.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-3, verbose=True)
# Out:
# Iteration: 0, previous point: [12.36284992  5.65819631], current point: [4. 0.], F(current point): 34.0
# Starting dimension 0 optimization
# Round: 0,	x: 3.506664954809325,	F'(x): 73.99999999968543,	F''(x): 149.9994795040038
# Round: 1,	x: 3.4005485028507447,	F'(x): 11.201687148698623,	F''(x): 105.56032492559096
# Round: 2,	x: 3.3957010413573863,	F'(x): 0.4690634726856046,	F''(x): 96.7647650895742
# Starting dimension 1 optimization
# Round: 0,	x: -0.08549201533276303,	F'(x): 1.0615711245165471,	F''(x): -12.417196160185993
# Round: 1,	x: -0.257489769868211,	F'(x): 2.120642816016982,	F''(x): -12.329479659456409
# Round: 2,	x: -0.6180772461496695,	F'(x): 4.190584724472757,	F''(x): -11.621548168250227
# Round: 3,	x: -1.612830147401036,	F'(x): 7.791887132491126,	F''(x): -7.8329875918825556
# Round: 4,	x: -1.8419617719648302,	F'(x): 4.307087772548179,	F''(x): 18.797439160778136
# Round: 5,	x: -1.8043519578433733,	F'(x): -1.0642311421782402,	F''(x): 28.296633924895783
# ...

# %%
powell.find_min(func, np.array([4., 0.], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [5.62355752 8.7845337 ], current point: [4. 0.], F(current point): 34.0
# Starting dimension [1. 0.] optimization
# Round: 0,	x: -0.4933350451906749,	F'(x): 73.99999999968543,	F''(x): 149.9994795040038
# Round: 1,	x: -0.5994514971492554,	F'(x): 11.201687148698623,	F''(x): 105.56032492559096
# Round: 2,	x: -0.6042989595315679,	F'(x): 0.46906347259678677,	F''(x): 96.7647473260058
# Starting dimension [0. 1.] optimization
# Round: 0,	x: -0.0854920143599809,	F'(x): 1.0615711124373206,	F''(x): -12.417196160185993
# Round: 1,	x: -0.2574895191684421,	F'(x): 2.1206427923026183,	F''(x): -12.329497423024803
# Round: 2,	x: -0.6180750903214476,	F'(x): 4.1905817997900385,	F''(x): -11.621601458955409
# Round: 3,	x: -1.6128303462653513,	F'(x): 7.791870235962505,	F''(x): -7.8329520647457676
# Round: 4,	x: -1.841961500961095,	F'(x): 4.307084027965757,	F''(x): 18.79746136523863
# Round: 5,	x: -1.8043520668442743,	F'(x): -1.0642234791857774,	F''(x): 28.296716081399605
# ...

# %%
simplex.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 simplex.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.simplex' has no attribute 'find_min'

# %%
nelder_mead.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nelder_mead.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.nelder_mead' has no attribute 'find_min'

# %%
gradient_descent.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [5.53926706 6.96384767], current point: [4. 0.], F(current point): 34.0
# Gradient in current point: 74.67261881001545
# Iteration: 1, previous point: [4. 0.], current point: [ 3.00900757 -0.1339179 ], F(current point): 20.110725295560684
# Gradient in current point: 33.04104947082035
# Iteration: 2, previous point: [ 3.00900757 -0.1339179 ], current point: [ 4.00711595 -0.07243897], F(current point): 33.77160451487347
# Gradient in current point: 74.70907091252613
# Iteration: 3, previous point: [ 4.00711595 -0.07243897], current point: [ 3.01768812 -0.21746505], F(current point): 19.940809034492446
# Gradient in current point: 33.36125590008002
# Iteration: 4, previous point: [ 3.01768812 -0.21746505], current point: [ 4.01740119 -0.19351125], F(current point): 33.1368477526831
# Gradient in current point: 74.5897754552708
# ...

# %%
steepest_gradient_descent.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [12.65275629  3.72863532], current point: [4. 0.], F(current point): 34.0
# Gradient in current point: 74.67261881001545
# Round: 0,	x: 0.49328718443990716,	F'(x): -74.67261881473064,	F''(x): 151.37757714001052
# Round: 1,	x: 0.597014777970308,	F'(x): -11.12202192894429,	F''(x): 107.22336796220587
# Round: 2,	x: 0.6015406737409855,	F'(x): -0.4465053211610836,	F''(x): 98.65567918154737
# Round: 3,	x: 0.6015491511166676,	F'(x): -0.0008332201595351306,	F''(x): 98.28751146301327
# Iteration: 1, previous point: [4. 0.], current point: [ 3.40386934 -0.0805582 ], F(current point): 13.141324333054381
# Gradient in current point: 2.18794473545998
# Round: 0,	x: 0.15763503143221344,	F'(x): -2.1879447356099035,	F''(x): -13.879812854611371
# Round: 1,	x: 0.4885300085496036,	F'(x): -4.317999063996325,	F''(x): -13.049454850033724
# Round: 2,	x: 1.3478840029295638,	F'(x): -8.107878525098755,	F''(x): -9.434852898948519
# ...

# %%
conjugate_descent.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [4.67952416 2.00885717], current point: [4. 0.], F(current point): 34.0
# Gradient in current point: 74.67261881001545
# Round: 0,	x: 0.49328718443990716,	F'(x): -74.67261881473064,	F''(x): 151.37757714001052
# Round: 1,	x: 0.597014777970308,	F'(x): -11.12202192894429,	F''(x): 107.22336796220587
# Round: 2,	x: 0.6015406737409855,	F'(x): -0.4465053211610836,	F''(x): 98.65567918154737
# Round: 3,	x: 0.6015491511166676,	F'(x): -0.0008332201595351306,	F''(x): 98.28751146301327
# Iteration: 1, previous point: [4. 0.], current point: [ 3.40386934 -0.0805582 ], F(current point): 13.141324333054381
# Gradient in current point: 2.18794473545998
# Round: 0,	x: 0.026977217126028623,	F'(x): -2.187944738185621,	F''(x): 81.10342619715992
# Round: 1,	x: 0.027304165069169172,	F'(x): -0.025891061739002904,	F''(x): 79.19016553614709
# Iteration: 2, previous point: [ 3.40386934 -0.0805582 ], current point: [ 3.38046764 -0.11127293], F(current point): 13.111574565122236
# ...

# %%
newton.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 newton.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.newton' has no attribute 'find_min'

# %%
random_search_with_return.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 random_search_with_return.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.random_search_with_return' has no attribute 'find_min'

# %%
best_sample.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 best_sample.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.best_sample' has no attribute 'find_min'

# %%
complex.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 complex.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.complex' has no attribute 'find_min'

# %%
iterative_random_search.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 iterative_random_search.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.iterative_random_search' has no attribute 'find_min'

# %%
random_search_radius.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 random_search_radius.find_min(func, np.array([4, 0], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.random_search_radius' has no attribute 'find_min'

# %% [markdown]
# ## Rosenbrock Function
#
# The Rosenbrock function, also known as the Rosenbrock's valley or Rosenbrock's banana function, is a non-convex function used to test optimization algorithms. It is defined as:
#
# $\ f(x, y) = (1 - x)^2 + 100(y - x^2)^2 $
#
# ### Extremum Points
#
# The function has one global minimum:
#
# - **Global Minimum:**
#   - $\ f(1, 1) = 0 $

# %%
func = lambda point: (1 - point[0]) ** 2 + 100 * (point[1] - point[0] ** 2) ** 2

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
z = func(np.array([x, y]))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

plt.show()

# %%
gauss_seidel.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  6.00852842 308.41471149], current point: [  0. 300.], F(current point): 9000001.0
# Starting dimension 0 optimization
# Round: 0,	x: 1.666718410431543e-05,	F'(x): -1.9999220967292783,	F''(x): -119991.60051345824
# Round: 1,	x: 5.0001552312946285e-05,	F'(x): -3.9998441934585567,	F''(x): -119991.60051345824
# Round: 2,	x: 0.00011664158334475389,	F'(x): -7.999967783689498,	F''(x): -120047.47986793517
# Round: 3,	x: 0.00024991594709397797,	F'(x): -15.996769070625303,	F''(x): -120028.85341644286
# Round: 4,	x: 0.0005165132771157103,	F'(x): -31.9894403219223,	F''(x): -119991.60051345824
# Round: 5,	x: 0.0010495564180219795,	F'(x): -63.980557024478905,	F''(x): -120028.85341644286
# Round: 6,	x: 0.0021161682192642156,	F'(x): -127.94472277164458,	F''(x): -119954.34761047362
# Round: 7,	x: 0.00424845561839519,	F'(x): -255.93601167201993,	F''(x): -120028.85341644286
# Round: 8,	x: 0.008513143651919946,	F'(x): -511.80617883801455,	F''(x): -120010.22696495055
# ...

# %%
hooke_jeeves.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  8.35266522 302.69196684], current point: [  0. 300.], F(current point): 9000001.0
# Trial vector: [10. 10.]
# F(x): 9000001.0, F(x + h): 4000081.0, F(x - h): 4000121.0
# Trial vector: [10. 10.]
# F(x): 4000081.0, F(x + h): 4410081.0, F(x - h): 3610081.0
# Trial vector: [ 10. -10.]
# Iteration: 0, previous point: [  0. 300.], current point: [ 10. 290.], F(current point): 3610081.0
# Iteration: 1, previous point: [  0. 300.], current point: [ 10. 290.], F(current point): 3610081.0
# Trial vector: [10. 10.]
# F(x): 3610081.0, F(x + h): 1210361.0, F(x - h): 8410001.0
# Trial vector: [10. 10.]
# F(x): 1210361.0, F(x + h): 1000361.0, F(x - h): 1440361.0
# Trial vector: [10. 10.]
# Iteration: 1, previous point: [ 10. 290.], current point: [ 20. 300.], F(current point): 1000361.0
# Iteration: 2, previous point: [ 10. 290.], current point: [ 20. 300.], F(current point): 1000361.0
# Trial vector: [10. 10.]
# ...

# %%
rosenbrock.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-3, verbose=True)
# Out:
# Iteration: 0, previous point: [  0.55094075 305.71788961], current point: [  0. 300.], F(current point): 9000001.0
# Starting dimension 0 optimization
# Round: 0,	x: 1.666718410431543e-05,	F'(x): -1.9999220967292783,	F''(x): -119991.60051345824
# Round: 1,	x: 5.0001552312946285e-05,	F'(x): -3.9998441934585567,	F''(x): -119991.60051345824
# Round: 2,	x: 0.00011664158334475389,	F'(x): -7.999967783689498,	F''(x): -120047.47986793517
# Round: 3,	x: 0.00024991594709397797,	F'(x): -15.996769070625303,	F''(x): -120028.85341644286
# Round: 4,	x: 0.0005165132771157103,	F'(x): -31.9894403219223,	F''(x): -119991.60051345824
# Round: 5,	x: 0.0010495564180219795,	F'(x): -63.980557024478905,	F''(x): -120028.85341644286
# Round: 6,	x: 0.0021161682192642156,	F'(x): -127.94472277164458,	F''(x): -119954.34761047362
# Round: 7,	x: 0.00424845561839519,	F'(x): -255.93601167201993,	F''(x): -120028.85341644286
# Round: 8,	x: 0.008513143651919946,	F'(x): -511.80617883801455,	F''(x): -120010.22696495055
# ...

# %%
powell.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  6.30196642 305.0451153 ], current point: [  0. 300.], F(current point): 9000001.0
# Starting dimension [1. 0.] optimization
# Round: 0,	x: 1.666718410431543e-05,	F'(x): -1.9999220967292783,	F''(x): -119991.60051345824
# Round: 1,	x: 5.0001552312946285e-05,	F'(x): -3.9998441934585567,	F''(x): -119991.60051345824
# Round: 2,	x: 0.00011664158334475389,	F'(x): -7.999967783689498,	F''(x): -120047.47986793517
# Round: 3,	x: 0.00024991594709397797,	F'(x): -15.996769070625303,	F''(x): -120028.85341644286
# Round: 4,	x: 0.0005165132771157103,	F'(x): -31.9894403219223,	F''(x): -119991.60051345824
# Round: 5,	x: 0.0010495564180219795,	F'(x): -63.980557024478905,	F''(x): -120028.85341644286
# Round: 6,	x: 0.0021161682192642156,	F'(x): -127.94472277164458,	F''(x): -119954.34761047362
# Round: 7,	x: 0.00424845561839519,	F'(x): -255.93601167201993,	F''(x): -120028.85341644286
# ...

# %%
simplex.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 simplex.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.simplex' has no attribute 'find_min'

# %%
nelder_mead.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 nelder_mead.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
#
# AttributeError: module 'optim.UnconditionalMultiDim.nelder_mead' has no attribute 'find_min'

# %%
gradient_descent.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  0.94961727 301.96373512], current point: [  0. 300.], F(current point): 9000001.0
# Gradient in current point: 59999.99990294557
# Iteration: 1, previous point: [  0. 300.], current point: [3.3332035e-05 2.9900000e+02], F(current point): 8940100.99990012
# Gradient in current point: 59800.000229609715
# Iteration: 2, previous point: [3.3332035e-05 2.9900000e+02], current point: [8.3385951e-05 2.9850000e+02], F(current point): 8910225.999600865
# Gradient in current point: 59700.00101765111
# Iteration: 3, previous point: [8.3385951e-05 2.9850000e+02], current point: [1.33453119e-04 2.98250000e+02], F(current point): 8895307.249152394
# Gradient in current point: 59650.00250420941
# Iteration: 4, previous point: [1.33453119e-04 2.98250000e+02], current point: [1.71006963e-04 2.98125000e+02], F(current point): 8887852.561232163
# Gradient in current point: 59625.004059470135
# ...

# %%
steepest_gradient_descent.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  0.66625519 305.14240582], current point: [  0. 300.], F(current point): 9000001.0
# Gradient in current point: 59999.99990294557
# Round: 0,	x: 292.8386786363636,	F'(x): -59999.99986961483,	F''(x): 204.89096641540525
# Round: 1,	x: 299.971764631517,	F'(x): -1432.2462403924872,	F''(x): 200.78914531040934
# Round: 2,	x: 299.999900504606,	F'(x): -5.627182080503167,	F''(x): 200.0002652380317
# Iteration: 1, previous point: [  0. 300.], current point: [9.99960718e-03 9.96620477e-05], F(current point): 0.9801007777878444
# Gradient in current point: 1.9799994660023241
# Round: 0,	x: -0.9519891038194866,	F'(x): -1.9799994660008033,	F''(x): 2.079855176972955
# Round: 1,	x: -0.6349583684932617,	F'(x): -338.2118742301543,	F''(x): 1066.8109950984215
# Round: 2,	x: -0.42064880963958406,	F'(x): -100.8698206693026,	F''(x): 470.67345576579095
# Round: 3,	x: -0.27134610824216454,	F'(x): -30.507920324795986,	F''(x): 204.3360236569924
# ...

# %%
conjugate_descent.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
# Out:
# Iteration: 0, previous point: [  4.21340001 302.06671402], current point: [  0. 300.], F(current point): 9000001.0
# Gradient in current point: 59999.99990294557
# Round: 0,	x: 292.8386786363636,	F'(x): -59999.99986961483,	F''(x): 204.89096641540525
# Round: 1,	x: 299.971764631517,	F'(x): -1432.2462403924872,	F''(x): 200.78914531040934
# Round: 2,	x: 299.999900504606,	F'(x): -5.627182080503167,	F''(x): 200.0002652380317
# Iteration: 1, previous point: [  0. 300.], current point: [9.99960718e-03 9.96620477e-05], F(current point): 0.9801007777878444
# Gradient in current point: 1.9799994660023241
# Round: 0,	x: 0.009425578898129927,	F'(x): -1.9799994241675998,	F''(x): 210.06661188316397
# Round: 1,	x: 0.009178825315338313,	F'(x): 0.05470786897388002,	F''(x): 221.7105354862525
# Round: 2,	x: 0.009178653922410594,	F'(x): 3.79469067279814e-05,	F''(x): 221.40299038575503
# ...

# %%
newton.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)

# %%
random_search_with_return.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)

# %%
best_sample.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)

# %%
complex.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)

# %%
iterative_random_search.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)

# %%
random_search_radius.find_min(func, np.array([0, 300], dtype=np.float64), ndim=2, eps=1e-5, verbose=True)
